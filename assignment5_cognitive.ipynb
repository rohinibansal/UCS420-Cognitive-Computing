# %% [markdown]
# Q.1 For the array gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]'), Find
#
# i. Sum of all elements
#
# ii. Sum of all elements row-wise
#
# iii. Sum of all elements column-wise

# %%
#1
import numpy as np
gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]')
print(gfg)
sum=np.sum(gfg)
print(sum)
# Out:
# [[ 4  1  9]
#  [12  3  1]
#  [ 4  5  6]]
# 45

# %%
#2
sum_rows=np.sum(gfg,axis=1)
print(sum_rows)
# Out:
# [[14]
#  [16]
#  [15]]

# %%
#3
sum_cols=np.sum(gfg,axis=0)
print(sum_cols)
# Out:
# [[20  9 16]]

# %% [markdown]
# Q.2 (a)For the array: array = np.array([10, 52, 62, 16, 16, 54, 453]), find
#
# i. Sorted array
#
# ii. Indices of sorted array
#
# iii. 4 smallest elements
#
# iv. 5 largest elements
#
# (b) For the array: array = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0]), find
#
# i. Integer elements only
#
# ii. Float elements only

# %%
#a
array=np.array([10, 52, 62, 16, 16, 54, 453])
print(array)
#1
sorted_arr=np.sort(array)
print(sorted_arr)
# Out:
# [ 10  52  62  16  16  54 453]
# [ 10  16  16  52  54  62 453]

# %%
#2
indices=np.argsort(array)
print(indices)
# Out:
# [0 3 4 1 5 2 6]

# %%
#3
smallest_4=np.sort(array)[:4]
print(smallest_4)
# Out:
# [10 16 16 52]

# %%
#4
largest_4=np.sort(array)[-4:]
print(largest_4)
# Out:
# [ 52  54  62 453]

# %%
#b
array = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0])
print(array)
#1
int_elements=array[array==array.astype(int)]
print(int_elements)
# Out:
# [1.  1.2 2.2 2.  3.  2. ]
# [1. 2. 3. 2.]

# %%
#2
float_elements=array[array==array.astype(float)]
print(float_elements)
# Out:
# [1.  1.2 2.2 2.  3.  2. ]

# %% [markdown]
# Ques 3: You are given a weekly sales dataset and need to perform various operations
# using NumPy broadcasting.
#
# a) Generate your unique sales dataset:
# Take the sum of the ASCII values of the initials of your first and last
# name. Call this value X. (If your initials are A B → ASCII sum = 65
# + 66 = 131 → sales = [131, 181, 231, 281, 331].)
#
# Create a NumPy array sales with values [X, X+50, X+100, X+150,
# X+200].

# %%
first_name=input('enter your first name:')
last_name=input('enter your last name:')
x=first_name[0]
y=last_name[0]
X=ord(x)+ord(y)
print(X)
# Out:
# enter your first name: rohini
# enter your last name: bansal
# 212

# %%
def create_array(X):
    sales=np.array([X,X+50,X+100,X+150,X+200])
    return sales
sales=create_array(X)
print(sales)
# Out:
# [212 262 312 362 412]

# %% [markdown]
# b) Compute your personalized tax rate as ((X % 5) + 5) / 100.
#
#  Use broadcasting to apply this tax rate to each sales value.

# %%
tax_rate = ((X % 5) + 5) / 100
taxes = sales * tax_rate
print("Taxes on sales:", taxes)
# Out:
# Taxes on sales: [ 7.86 10.86 13.86 16.86 19.86]

# %% [markdown]
# c) Adjust sales based on discount:
#
#  If sales < X+100, apply a 5% discount.
#
#  If sales >= X+100, apply a 10% discount.

# %%
discounted_sales = np.where(sales < X+100, sales * 0.95, sales * 0.90)
print("Sales after discount:", discounted_sales)
# Out:
# Sales after discount: [124.45 171.95 207.9  252.9  297.9 ]

# %% [markdown]
# d)Expand sales data for multiple weeks:
#
#  Create a 3×5 matrix representing three weeks of sales by stacking
# sales three times using broadcasting.
#
#  Increase sales by 2% per week using element-wise broadcasting.

# %%
weekly_sales = np.vstack([discounted_sales] * 3)
weekly_increase = np.array([1.00, 1.02, 1.04]).reshape(3, 1)
adjusted_sales = weekly_sales * weekly_increase
print("Weekly adjusted sales:\n", adjusted_sales)
# Out:
# Weekly adjusted sales:
#  [[124.45  171.95  207.9   252.9   297.9  ]
#  [126.939 175.389 212.058 257.958 303.858]
#  [129.428 178.828 216.216 263.016 309.816]]

# %% [markdown]
# Q4. Generate x values using np.linspace() from -10 to 10 with 100 points. Use
# each function from the list below and compute y values using NumPy:
#
#  Y = x2
#
#  Y = sin(x)
#
#  Y = ex
#
#  Y = log(|x| + 1)
#
# Plot the chosen function using Matplotlib. Add title, labels, and grid for clarity.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)

y1 = x**2
plt.figure(figsize=(6, 4))
plt.plot(x, y1, label='Y = x^2')
plt.title('Plot of Y = x^2')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.legend()
plt.grid()
plt.show()

x = np.linspace(-10, 10, 100)
y2 = np.sin(x)
plt.figure(figsize=(6, 4))
plt.plot(x, y2, label='Y = sin(x)', color='r')
plt.title('Plot of Y = sin(x)')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.legend()
plt.grid()
plt.show()

x = np.linspace(-10, 10, 100)
y3 = np.exp(x)
plt.figure(figsize=(6, 4))
plt.plot(x, y3, label='Y = e^x', color='g')
plt.title('Plot of Y = e^x')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.legend()
plt.grid()
plt.show()

x = np.linspace(-10, 10, 100)
y4 = np.log(np.abs(x) + 1)
plt.figure(figsize=(6, 4))
plt.plot(x, y4, label='Y = log(|x| + 1)', color='m')
plt.title('Plot of Y = log(|x| + 1)')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.legend()
plt.grid()
plt.show()
